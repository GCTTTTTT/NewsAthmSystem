# %%
import pandas as pd
from flask import Flask, jsonify
from flask_cors import CORS  # 导入CORS模块
from gevent import pywsgi


# 读取total_result_pure.csv文件并提取id列的前20条数据以及对应的total_rank字段
total_result = pd.read_csv('./datasets/total_result_pure.csv')
id_and_rank = total_result[['id', 'total_rank']].head(20)

# 读取news_2024-03-02_processed.csv文件
news_data = pd.read_csv('./datasets/Data231202_processed.csv')

# 读取website_Rank_new_FIX.csv文件
website_rank = pd.read_csv('./datasets/website_Rank_new_FIX.csv')

# 根据id列表在news_data中读取对应id的数据
merged_data = pd.merge(id_and_rank, news_data, on='id')

# 根据website_id读取website_Rank_new_FIX.csv文件中的url字段
merged_data = pd.merge(merged_data, website_rank, on='website_id')


# 将每个id对应的数据包装成json格式
result_json = []
for index, row in merged_data.iterrows():
    data_dict = {
        'id': row['id'],
        'total_rank': row['total_rank'],
        'url': row['url'],
        'website_id': row['website_id'],
        'request_url': row['request_url'],
        'response_url': row['response_url'],
        'category1': row['category1'],
        'category2': row['category2'],
        'title': row['title'],
        'abstract': row['abstract'],
        'body': row['body'],
        'pub_time': row['pub_time'],
        'cole_time': row['cole_time'],
        'images': row['images'],
        'language_id': row['language_id'],
        'md5': row['md5']
    }
    result_json.append(data_dict)

# 使用Flask创建算法接口
app = Flask(__name__)
CORS(app)  # 添加跨域支持

@app.route('/', methods=['GET'])
def get_data_test():
    print("!!!!!!!!!111")

@app.route('/get_data', methods=['GET'])
def get_data():
    print("!")
    data = {
        'code': '200',
        'message': 'success',
        'Content-Type': 'application/json; charset=utf-8',
        'news': result_json
    }
    return jsonify(data)

if __name__ == '__main__':
    # app.run(debug=True)
    server = pywsgi.WSGIServer(('127.0.0.1', 5399), app)
    server.serve_forever()
# Out:
# !
# 127.0.0.1 - - [2024-04-03 11:04:10] "GET /get_data HTTP/1.1" 200 313060 0.002491
# 127.0.0.1 - - [2024-04-03 11:04:10] "GET /favicon.ico HTTP/1.1" 404 363 0.000723

# %%
# FullArt:
{
	"artId": 20171864,
	"artTitle": "\n\tচট্টগ্রামে ইফতার সামগ্রী বিতরণ \nদেশের মানুষকে গরিব বানিয়ে দিয়েছে সরকার : ডা: শাহাদাত \n",
	"artContent": "চট্টগ্রাম মহানগর বিএনপির আহ্বায়ক ডা: শাহাদাত হোসেন বলেছেন, দেশের সাধারণ মানুষ কষ্টের মধ্যে দিন যাপন করছে। পবিত্র রমজান মাসে নিত্যপ্রয়োজনীয় চাল ডাল তেলসহ বিদ্যুৎ ও গ্যাসের মূল্য লাগামহীনভাবে বৃদ্ধি পেয়েছে। এতে করে মানুষ আর্থিক দিক থেকে আক্রান্ত হচ্ছেন। তাদের প্রকৃত আয় অনেক কমে গেছে। মানুষ মধ্যবিত্ত থেকে নিম্নবিত্তে চলে গেছে। দেশে এমন সরকার রয়েছে যারা নির্বাচিত নন। তাই জনগণের প্রতি সরকারের কোনো দরদ নেই। দেশের মানুষকে গরিব বানিয়ে দিয়েছে সরকার। তিনি গতকাল মঙ্গলবার বিকেলে অলঙ্কার মোড় আবদুল আলী নগরে পবিত্র মাহে রমজান উপলক্ষে উত্তর পাহাড়তলী ওয়ার্ডের অসহায় হতদরিদ্র মানুষ ও ইমাম-মুয়াজ্জিনের মাঝে ইফতার ও সাহরিসামগ্রী বিতরণকালে প্রধান অতিথির বক্তব্যে এসব কথা বলেন। এ সময় তিনি সমাজের বিত্তশালী ব্যক্তি ও বিএনপি নেতাকর্মীদের অসহায় হতদরিদ্র মানুষের সহয়তায় এগিয়ে আসার আহ্বান জানান। এতে বিশেষ অতিথি হিসেবে উপস্থিত ছিলেন চট্টগ্রাম মহানগর বিএনপির সদস্যসচিব আবুল হাশেম বক্কর। চট্টগ্রাম মহানগর যুবদলের যুগ্ম সম্পাদক এস এম জিয়াউল হুদার (শাহরিয়ার জিয়া) সভাপতিত্বে ও সহসভাপতি ফজলুল হক সমুনের পরিচালনায় বক্তব্য রাখেন মহানগর বিএনপি নেতা নূরুল আকবর কাজল, আলী আজম চৌধুরী, আকবর শাহ থানা বিএনপির সাধারন সম্পাদক মাঈনুদ্দিন চৌধুরী মাঈনু, মহানগর যুবদলের সহসভাপতি নুর আহমদ গুড্ডু, স্বেচ্ছাসেবক দলের সাংগঠনিক সম্পাদক জিয়াউর রহমান জিয়া, জাসাসের শেখ জামিল হোসেন প্রমুখ।\n \n",
	"artSpider": "",
	"artType": "আজকের পত্রিকা",
	"artTags": "",
	"artImageUrl": "[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]",
	"artTime": "2024-03-13T00:00:00.000+0000",
	"artLegal": 0,
	"artCusId": 582,
	"websiteId": 2244,
	"websiteUrl": "https://www.dailynayadiganta.com",
	"customer": {
		"cusId": 582,
		"cusName": "admin",
		"cusPass": null,
		"cusSpider": "",
		"cusAvatarUrl": "http://localhost:8080/img/Man.png",
		"cusStyle": "这个人很懒, 什么都没写",
		"cusGender": 0,
		"cusTime": "2024-03-14T21:53:09.000+0000",
		"cusLegal": 0
	},
	"artFeature": {
		"afcId": 710,
		"afcArtId": 20171864,
		"afcLikeNum": 0,
		"afcDislikeNum": 0,
		"afcComNum": 0,
		"afcRepNum": 0,
		"afcReadNum": 0,
		"afcArtTime": null
	},
	"cusArtBehavior": {
		"cusId": 582,
		"artId": 20171864,
		"preference": 0,
		"artAuthor": false,
		"read": false,
		"follow": null
	}
}

# %%
# 现在前端返回的字符串（index中的TinyArticle）
{"artId":20171864,
 "artTitle":"\n\tচট্টগ্রামে ইফতার সামগ্রী বিতরণ \nদেশের মানুষকে গরিব বানিয়ে দিয়েছে সরকার : ডা: শাহাদাত \n",
 "artContent":null,
 "artSpider":"",
 "artType":"আজকের পত্রিকা",
 "artTags":"",
 "artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]",
 "artTime":"2024-03-13T00:00:00.000+0000",
 "artLegal":0,
 "artCusId":582,
 "websiteId":null,
 "websiteUrl":null,
 "customer":{"cusId":582,"cusName":"admin",
             "cusPass":null,
             "cusSpider":"",
             "cusAvatarUrl":"http://localhost:8080/img/Man.png",
             "cusStyle":"这个人很懒, 什么都没写",
             "cusGender":0,
             "cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},
 "artFeature":{"afcId":710,"afcArtId":20171864,
               "afcLikeNum":0,"afcDislikeNum":0,
               "afcComNum":0,"afcRepNum":0,
               "afcReadNum":0,
               "afcArtTime":null},
 "cusArtBehavior":null}
{"artId":20168120,"artTitle":"\n\nহাইতির প্রধানমন্ত্রী এরিয়েল হেনরির পদত্যাগ\n","artContent":null,"artSpider":"","artType":"আজকের পত্রিকা","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":653,"afcArtId":20168120,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20168002,"artTitle":"\n\nহুমকি পেলে পারমাণবিক অস্ত্র ব্যবহারে প্রস্তুত রাশিয়া : পুতিন\n","artContent":null,"artSpider":"","artType":"আন্তর্জাতিক","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/article/202403/821057_163.jpg\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":641,"afcArtId":20168002,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20349885,"artTitle":"\n\nএমভি আব্দুল্লাহর চিফ অফিসার আতিক উল্লাহ খানের পরিবারের সবাই চিন্তিত\n","artContent":null,"artSpider":"","artType":"দেশ","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":1048,"afcArtId":20349885,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20171711,"artTitle":"\n\nবড়লেখায় পাহাড় কেটে রাস্তা সম্প্রসারণে বেরিয়ে এলো বিরল শিলাখণ্ড \n","artContent":null,"artSpider":"","artType":"আজকের পত্রিকা","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":692,"afcArtId":20171711,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20171791,"artTitle":"\n\nপিডব্লিউডি জয়ী\n","artContent":null,"artSpider":"","artType":"আজকের পত্রিকা","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":702,"afcArtId":20171791,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20168169,"artTitle":"\n\nইসলামে কেন রোজার প্রবর্তন\n","artContent":null,"artSpider":"","artType":"আজকের পত্রিকা","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":664,"afcArtId":20168169,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}
{"artId":20349885,"artTitle":"\n\nএমভি আব্দুল্লাহর চিফ অফিসার আতিক উল্লাহ খানের পরিবারের সবাই চিন্তিত\n","artContent":null,"artSpider":"","artType":"দেশ","artTags":"","artImageUrl":"[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]","artTime":"2024-03-13T00:00:00.000+0000","artLegal":0,"artCusId":582,"websiteId":null,"websiteUrl":null,"customer":{"cusId":582,"cusName":"admin","cusPass":null,"cusSpider":"","cusAvatarUrl":"http://localhost:8080/img/Man.png","cusStyle":"这个人很懒, 什么都没写","cusGender":0,"cusTime":"2024-03-14T21:53:09.000+0000","cusLegal":0},"artFeature":{"afcId":1048,"afcArtId":20349885,"afcLikeNum":0,"afcDislikeNum":0,"afcComNum":0,"afcRepNum":0,"afcReadNum":0,"afcArtTime":null},"cusArtBehavior":null}

# %%
[{
	"artId": 20171864,
	"artTitle": "\n\tচট্টগ্রামে ইফতার সামগ্রী বিতরণ \nদেশের মানুষকে গরিব বানিয়ে দিয়েছে সরকার : ডা: শাহাদাত \n",
	"artContent": null,
	"artSpider": "",
	"artType": "আজকের পত্রিকা",
	"artTags": "",
	"artImageUrl": "[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]",
	"artTime": "2024-03-13T00:00:00.000+0000",
	"artLegal": 0,
	"artCusId": 582,
	"websiteId": null,
	"websiteUrl": null,
	"customer": {
		"cusId": 582,
		"cusName": "admin",
		"cusPass": null,
		"cusSpider": "",
		"cusAvatarUrl": "http://localhost:8080/img/Man.png",
		"cusStyle": "这个人很懒, 什么都没写",
		"cusGender": 0,
		"cusTime": "2024-03-14T21:53:09.000+0000",
		"cusLegal": 0
	},
	"artFeature": {
		"afcId": 710,
		"afcArtId": 20171864,
		"afcLikeNum": 0,
		"afcDislikeNum": 0,
		"afcComNum": 0,
		"afcRepNum": 0,
		"afcReadNum": 0,
		"afcArtTime": null
	},
	"cusArtBehavior": null
}, {
	"artId": 20168120,
	"artTitle": "\n\nহাইতির প্রধানমন্ত্রী এরিয়েল হেনরির পদত্যাগ\n",
	"artContent": null,
	"artSpider": "",
	"artType": "আজকের পত্রিকা",
	"artTags": "",
	"artImageUrl": "[\"https://www.dailynayadiganta.com/resources/img/sitesetup/1_1.png\"]",
	"artTime": "2024-03-13T00:00:00.000+0000",
	"artLegal": 0,
	"artCusId": 582,
	"websiteId": null,
	"websiteUrl": null,
	"customer": {
		"cusId": 582,
		"cusName": "admin",
		"cusPass": null,
		"cusSpider": "",
		"cusAvatarUrl": "http://localhost:8080/img/Man.png",
		"cusStyle": "这个人很懒, 什么都没写",
		"cusGender": 0,
		"cusTime": "2024-03-14T21:53:09.000+0000",
		"cusLegal": 0
	},
	"artFeature": {
		"afcId": 653,
		"afcArtId": 20168120,
		"afcLikeNum": 0,
		"afcDislikeNum": 0,
		"afcComNum": 0,
		"afcRepNum": 0,
		"afcReadNum": 0,
		"afcArtTime": null
	},
	"cusArtBehavior": null
}]

# %%
[{
	"abstract": "নওগাঁয় বিএনপির পদযাত্রা কর্মসূচি ঘিরে হামলা ও সংঘর্ষের ঘটনায় জাতীয় দলের সাবেক ফুটবলার এনামুল হকসহ বিএনপি ও সহযোগী সংগঠনের নেতা-কর্মীর বিরুদ্ধে মামলা করা হয়েছে। নওগাঁ সদর উপজেলা ছাত্রলীগের সদস্য মাহবুবুল আলম বাদী হয়ে মারধর ও গাড়ি ভাঙচুরের অভিযোগে আজ রোববার সকালে নওগাঁ সদর থানায় এ মামলা করেন।",
	"artContent": "নওগাঁয় বিএনপির পদযাত্রা কর্মসূচি ঘিরে হামলা ও সংঘর্ষের ঘটনায় জাতীয় দলের সাবেক ফুটবলার এনামুল হকসহ বিএনপি ও সহযোগী সংগঠনের নেতা-কর্মীর বিরুদ্ধে মামলা করা হয়েছে। নওগাঁ সদর উপজেলা ছাত্রলীগের সদস্য মাহবুবুল আলম বাদী হয়ে মারধর ও গাড়ি ভাঙচুরের অভিযোগে আজ রোববার সকালে নওগাঁ সদর থানায় এ মামলা করেন।\nনওগাঁ সদর থানার ভারপ্রাপ্ত কর্মকর্তা (ওসি) ফয়সাল বিন আহসান বলেন, মারধর ও গাড়ি ভাঙচুরের অভিযোগে মাহবুবুল আলম নামের এক ব্যক্তি ৩০ জনের নাম উল্লেখ করে এবং অজ্ঞাত ৫০ থেকে ৬০ জনকে আসামি করে মামলাটি করেছেন।বিএনপি ও স্থানীয় সূত্রে জানা যায়, গতকাল শনিবার দুপুরে নওগাঁ সদর উপজেলার তিলকপুর ইউনিয়নের আদম দুর্গাপুর নতুনহাট এলাকায় বিএনপির পদযাত্রা কর্মসূচিতে হামলা চালান আওয়ামী লীগ ও এর সহযোগী সংগঠনের নেতা-কর্মীরা। এ সময় উভয় পক্ষের মধ্যে সংঘর্ষ ও পাল্টাপাল্টি ধাওয়ার ঘটনা ঘটে। এতে উভয় পক্ষের সাতজন নেতা-কর্মী আহত হন। এ ছাড়া সংঘর্ষের সময় একটি মোটরসাইকেল ভাঙচুরের ঘটনা ঘটে।\nনওগাঁয় বিএনপির পদযাত্রায় হামলার অভিযোগ\nএ ঘটনায় জাতীয় দলের সাবেক ফুটবলার ও নওগাঁ জেলা বিএনপির সাবেক ক্রীড়াবিষয়ক সম্পাদক এনামুল হক, তিলকপুর ইউনিয়ন বিএনপির সাধারণ সম্পাদক ইয়াসিন আলী, সাংগঠনিক সম্পাদক সাইফুল ইসলাম, যুবদলের কর্মী রুহুল, শাকিল সরদারসহ ৩০ জনের নাম উল্লেখ করে এবং অজ্ঞাতনামা আরও ৫০ থেকে ৬০ জনের বিরুদ্ধে মামলা করা হয়েছে।নওগাঁ সদর উপজেলা আওয়ামী লীগের সাংগঠনিক সম্পাদক ডি এম আওয়াল বলেন, ‘গতকাল এক সভা শেষে ফেরার পথে বিএনপির নেতা-কর্মীরা সামনে পড়েন। এ সময় তাঁরা আমাদের ওপর হামলা চালান। এতে আমাদের দুই কর্মী আহত হন। এ সময় একটি মোটরসাইকেল ভাঙচুর করা হয়।’\nমামলা করায় তীব্র প্রতিবাদ জানিয়েছেন নওগাঁ জেলা বিএনপির আহ্বায়ক আবু বক্কর সিদ্দিক। তিনি বলেন, ‘তিলকপুর ছাড়া জেলার ৯৮টি ইউনিয়নে আমরা শান্তিপূর্ণভাবে পদযাত্রা কর্মসূচি পালন করেছি। তিলকপুরে আওয়ামী লীগের কর্মীরা বিনা উসকানিতে আমাদের পদযাত্রায় বাধা ও হামলা করেছেন। এতে বিএনপি ও সহযোগী সংগঠনের পাঁচজন নেতা-কর্মী আহত হয়েছেন। উল্টো তাঁরাই আবার আমাদের নেতা-কর্মীদের বিরুদ্ধে মামলা দিয়েছেন। অথচ আমরা অভিযোগ করতে গেলে থানায় কোনো অভিযোগ নেওয়া হয়নি।’",
	
	"artId": 13485582,
	"artImageUrl": "[\"https://images.prothomalo.com/prothomalo-bangla/2023-02/b6ec9ca9-31ff-4a3a-afa7-a038280f99cf/Nao.jpg\"]",
	"artTime": "2023-12-02 20:44:45",
	"artTitle": "নওগাঁয় বিএনপির পদযাত্রা ঘিরে সংঘর্ষের ঘটনায় ৩০ নেতা-কর্মীর নামে মামলা",
	"artType": "রাজনীতি",
	"cole_time": "13/2/2023 01:44:53",
	"language_id": 1779,
	"md5": "8fc18be4d1836a8bb06a88f1ae4613a9",
	"request_url": "https://www.prothomalo.com/route-data.json?path=/bangladesh/district/43ar2f7j31",
	"response_url": "https://www.prothomalo.com/route-data.json?path=/bangladesh/district/43ar2f7j31",
	"total_rank": 1.0,
	"url": "https://www.prothomalo.com/",
	"website_id": 1921
	"customer": {
		"cusAvatarUrl": "http://localhost:8080/img/Man.png",
		"cusGender": 0,
		"cusId": 582,
		"cusLegal": 0,
		"cusName": "admin",
		"cusPass": null,
		"cusSpider": "",
		"cusStyle": "这个人很懒, 什么都没写",
		"cusTime": "2024-03-14T21:53:09.000+0000"
	},
    "artFeature": {
		"afcArtId": 20171864,
		"afcArtTime": null,
		"afcComNum": 0,
		"afcDislikeNum": 0,
		"afcId": 710,
		"afcLikeNum": 0,
		"afcReadNum": 0,
		"afcRepNum": 0
	},
	"cusArtBehavior": null,

}, {
	"abstract": "আওয়ামী লীগের সাধারণ সম্পাদক এবং সড়ক পরিবহন ও সেতুমন্ত্রী ওবায়দুল কাদের বলেছেন, বিএনপি-জামায়াত দেশে আবারো আগুন সন্ত্রাস শুরু করেছে। সিরাজগঞ্জে আওয়ামী লীগের শান্তি সমাবেশে হামলা হয়েছে।",
