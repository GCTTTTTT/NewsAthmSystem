# %%
import pandas as pd

# 读取 CSV 文件
# data = pd.read_csv('total_result_pure_2024-03-10_bert-base-multilingual-cased.csv')
# data = pd.read_csv('total_result_2024-03-09_bert-base-multilingual-cased.csv')
data = pd.read_csv('./MergeFiveDScore/mbert_BiLSTM_SelfAttention/total_result_pure_2024-03-11_mbert_BiLSTM_SelfAttention.csv')

# 去除 'title' 列中的多余换行符
data['title'] = data['title'].str.replace('\n', '')

# 打印前 20 条数据的 'title' 列和 'total_rank' 列
for index, row in data.head(20).iterrows():
    # print(row)
    print(row['title'])
    # print("Title:", row['title'], "| Total Rank:", row['total_rank'])
# Out:
# রেফায়েতপুর ইউনিয়ন পরিষদ উপ-নির্বাচন সমান ভোট পাওয়ায় লটারির মাধ্যমে ফলাফল ঘোষণা পরাজিতের প্রত্যাখ্যান
# আগুনে মারা যাওয়া সন্তানের বাবার আক্ষেপ বেইলি রোডে এখন এত নিরাপত্তা কেনদায়ীদের বিচারের মুখোমুখি করা হবে : স্বরাষ্ট্রমন্ত্রী
# রাজধানীসহ দেশের বিভিন্ন স্থানে জামায়াতের বিক্ষোভ দ্রব্যমূল্য নিয়ন্ত্রণ ও রমজানের পবিত্রতা রক্ষার দাবি
# পরিবেশমন্ত্রীর অভিযান  বনশ্রীতে বিধি লঙ্ঘন করে বাড়ি নির্মাণ করায় ১১ লাখ টাকা জরিমানা
#  নারীর রাজনৈতিক নেতৃত্ব বিকাশে প্রয়োজন অর্থনৈতিক ক্ষমতায়নডেমোক্র্যাসি ইন্টারন্যাশনালের আলোচনায় বক্তারা
# ভেড়ামারায় ৪ কিমি জুড়ে পানের বরজে আগুন শত কোটি টাকা ক্ষতির আশঙ্কা
# তথ্য চাওয়ায় কারাগারে পাঠানো নকলার সাংবাদিক শফিউজ্জামান রানাকে সাজা দেয়ার প্রদিবাদ
# টগড়া-চরখালী ফেরিকে জাহাজের ধাক্কা  পিরোজপুরে ১১ রুটে বাস চলাচল বন্ধ
# জেলা পরিষদ চেয়ারম্যান নির্বাচিত হয়ে পরিকল্পনার কথা জানালেন এমপি পত্নী
# খুলনায় মাদরাসার জমি দখলে ব্যর্থ হয়ে সুপারের পা ভেঙে দিয়েছে দুর্বৃত্তরা
# অধ্যাপক ডা. দীন মো. নূরুল হককে বিএসএমএমইউ’র ভিসি নিয়োগ দিয়ে প্রজ্ঞাপন জারি
# ...
